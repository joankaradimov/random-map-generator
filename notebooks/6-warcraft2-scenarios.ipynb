# %% [markdown]
# # Warcraft 2 scenarios
#
# Tilesets in Warcraft 2 are stored in file formats almost identical to the ones in Starcraft. Also - PUD files are use the same general sceme as the CHK files within SCM/SCX archives. With some tweaking of the code we can demonstrate working Warcraft 2 scenario parsing.

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import os
import sys

sys.path.append('../model')

import config
from warcraft2.game import *

# %%
game = Game(r'C:\Games\Warcraft II BNE')

# %%
scenarios = game.process_game_scenarios()

# %%
plt.figure(figsize=(15, 15))
tiny_scenarios = [s for s in scenarios if s.width == s.height == 64]
plt.imshow(tiny_scenarios[5].graphics);
